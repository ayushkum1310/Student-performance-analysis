# %% [markdown]
# # Importing the libraies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# %%
data=pd.read_csv("StudentsPerformance.csv")

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.describe().T
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# # Visulization/comparison

# %%
plt.figure(figsize=(10,9))
plt.xlabel("GENDER")
plt.title("Male vs female")

sns.countplot(data["gender"])
data["gender"].value_counts()
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# female    518
# male      482
# Name: gender, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.title("various group")
sns.countplot(data["race/ethnicity"])
data["race/ethnicity"].value_counts()
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
df=data.groupby("race/ethnicity").size()

# %%
df
# Out:
# race/ethnicity
# group A     89
# group B    190
# group C    319
# group D    262
# group E    140
# dtype: int64

# %%
df.plot(kind="pie",subplots=True,figsize=(8,6))
plt.tight_layout()
plt.title('Pie chart')
plt.ylabel("")
# Out:
# Text(117.67999999999999, 0.5, '')

# %%
plt.figure(figsize=(15,7))
g=sns.countplot(data["parental level of education"])
data["parental level of education"].value_counts()
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
plt.figure(figsize=(15,7))
sns.countplot(data["lunch"])
plt.title("Lunch coulumn analysis")
data["lunch"].value_counts()
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
plt.figure(figsize=(15,7))
sns.countplot(data["test preparation course"])
plt.title("Comparison between test prerparation course")
data["test preparation course"].value_counts()
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(data["math score"])
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='math score', ylabel='count'>

# %%
data["math score"].value_counts().plot.bar(figsize=(20,8))
plt.title("Comparison between math marks")
# Out:
# Text(0.5, 1.0, 'Comparison between math marks')

# %%
data["reading score"].value_counts().plot.bar(figsize=(20,8),color="r")
plt.title("Comparison between reading mark's")
# Out:
# Text(0.5, 1.0, "Comparison between reading mark's")

# %%
data["writing score"].value_counts().plot.bar(figsize=(20,8),color="orange")
plt.title("Comparison between writing score")
data["writing score"].value_counts()
# Out:
# 74    35
# 70    33
# 68    31
# 73    28
# 80    27
#       ..
# 28     1
# 35     1
# 19     1
# 22     1
# 23     1
# Name: writing score, Length: 77, dtype: int64

# %% [markdown]
# #                    outliers

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
sns.distplot(data["math score"])
plt.ylabel("")

plt.subplot(1,3,2)
sns.distplot(data["reading score"])
plt.ylabel("")


plt.subplot(1,3,3)
sns.distplot(data["writing score"])
plt.ylabel("")

plt.show()
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
np.random.seed(6)
sample_math_marks=np.random.choice(a=data["math score"],size=100)
print("sample mean of mayh score is:",sample_math_marks.mean())
print("population mean of the math score is :",data["math score"].mean())

sample_read_marks=np.random.choice(a=data["reading score"],size=100)
print("sample mean of reading is:",sample_read_marks.mean())
print("population mean of the readng is :",data["reading score"].mean())

sample_writing_marks=np.random.choice(a=data["writing score"],size=100)
print("sample mean of writing score is:",sample_writing_marks.mean())
print("population mean of the writing score is :",data["writing score"].mean())
# Out:
# sample mean of mayh score is: 63.12
# population mean of the math score is : 66.089
# sample mean of reading is: 68.5
# population mean of the readng is : 69.169
# sample mean of writing score is: 71.46
# population mean of the writing score is : 68.054

# %% [markdown]
# # comparison between the columns

# %%
plt.figure(figsize=(15,5))
plt.title("parental level of education vs test preparation course ")

sns.countplot(x="parental level of education",data=data,hue="test preparation course")
# Out:
# <AxesSubplot:title={'center':'parental level of education vs test preparation course '}, xlabel='parental level of education', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

sns.countplot(x="gender",data=data,hue="test preparation course")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

sns.countplot(x="race/ethnicity",data=data,hue="test preparation course")
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='count'>

# %% [markdown]
# # pass or fail

# %%
plt.figure(figsize=(15,8))
passmarks=40
plt.title("Pass in math")
data["pass_math"]=np.where(data["math score"]<passmarks,"Fail","Pass")
sns.countplot(data["pass_math"])
data["pass_math"].value_counts()
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Pass    960
# Fail     40
# Name: pass_math, dtype: int64

# %%
plt.figure(figsize=(15,8))
passmarks=40
plt.title("Pass in reading")
data["pass_reading"]=np.where(data["reading score"]<passmarks,"Fail","Pass")
sns.countplot(data["pass_reading"])
data["pass_reading"].value_counts()
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Pass    974
# Fail     26
# Name: pass_reading, dtype: int64

# %%
plt.figure(figsize=(15,8))
passmarks=40
plt.title("Pass in writing")
data["pass_writing"]=np.where(data["writing score"]<passmarks,"Fail","Pass")
sns.countplot(data["pass_writing"])
data["pass_writing"].value_counts()
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Pass    968
# Fail     32
# Name: pass_writing, dtype: int64

# %%
plt.figure(figsize=(20,8))
data["Total_score"]=data["math score"]+data["reading score"]+data["writing score"]
sns.countplot(data["Total_score"])
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total_score', ylabel='count'>

# %%
plt.subplots(figsize=(20,10))
data["Total_score"].value_counts().plot.bar(figsize=(40,8),color="cyan")
# Out:
# <AxesSubplot:>

# %%
data["Persentage"]=data["Total_score"]/3
data["Persentage"]=data["Persentage"].round()
plt.figure(figsize=(20,8))
data["Persentage"].value_counts().plot.bar(color="cyan")
data["Persentage"].value_counts()
# Out:
# 68.0    35
# 69.0    34
# 73.0    33
# 65.0    29
# 71.0    28
#         ..
# 34.0     1
# 37.0     1
# 29.0     1
# 9.0      1
# 18.0     1
# Name: Persentage, Length: 73, dtype: int64

# %%
data["Status"]=data.apply(lambda x: "Fail" if x["pass_math"]=="Fail" 
                         or x["pass_reading"]=="Fail" or
                         x["pass_writing"]=="Fail" else "Pass",axis=1)

# %%
plt.figure(figsize=(15,5))
sns.countplot(data["Status"])
data["Status"].value_counts()
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Pass    949
# Fail     51
# Name: Status, dtype: int64

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
data["pass_math"].value_counts().plot(kind="pie",autopct="%.2f%%")
plt.xlabel(" ")

plt.subplot(1,3,2)
data["pass_reading"].value_counts().plot(kind="pie",autopct="%.2f%%")
plt.xlabel(" ")

plt.subplot(1,3,3)
data["pass_writing"].value_counts().plot(kind="pie",autopct="%.2f%%")
plt.xlabel(" ")
# Out:
# Text(0.5, 0, ' ')

# %%
# Assigning grades according to the persentage:
# 0-40 ->E
# 40-60->D
# 60-70->C
# 70-80->B
# 80-90->A
# 90-100->O

def setgrades(persentage,statu):
    if statu=="Fail":
        return "E"
    if persentage>=90:
        return "O"
    if persentage>=80:
        return "A"
    if persentage>=70:
        return "B"
    if persentage>=60:
        return "C"
    if persentage>=40:
        return "D"
    else:
        return "E"

# %%
data["grades"]=data.apply(lambda x : setgrades(x["Persentage"],x["Status"]),axis=1)

# %%
data.grades.value_counts()
# Out:
# B    258
# C    256
# D    229
# A    152
# O     54
# E     51
# Name: grades, dtype: int64

# %%
data["grades"].value_counts().plot(kind="pie",autopct="%.2f%%",figsize=(10,10),shadow=True)
plt.legend()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=data["parental level of education"],hue=data["grades"],data=data)
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='count'>

# %%
plt.subplots(figsize=(15,5))
sns.countplot(x=data["grades"],data=data,hue=data["gender"])
# Out:
# <AxesSubplot:xlabel='grades', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# Out:
#                math score  reading score  writing score  Total_score  \
# math score       1.000000       0.817580       0.802642     0.918746
# reading score    0.817580       1.000000       0.954598     0.970331
# writing score    0.802642       0.954598       1.000000     0.965667
# Total_score      0.918746       0.970331       0.965667     1.000000
# Persentage       0.918442       0.970143       0.965643     0.999820
#
#                Persentage
# math score       0.918442
# reading score    0.970143
# writing score    0.965643
# Total_score      0.999820
# Persentage       1.000000

# %% [markdown]
# # preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["test preparation course"]=le.fit_transform(data["test preparation course"])

data['lunch']=le.fit_transform(data["lunch"])

# %%
data["race/ethnicity"]=data["race/ethnicity"].replace("group A",1)

# %%
data["race/ethnicity"]=data["race/ethnicity"].replace("group B",2)
data["race/ethnicity"]=data["race/ethnicity"].replace("group C",3)
data["race/ethnicity"]=data["race/ethnicity"].replace("group D",4)
data["race/ethnicity"]=data["race/ethnicity"].replace("group E",5)

# %%
data["race/ethnicity"].value_counts()
# Out:
# 3    319
# 4    262
# 2    190
# 5    140
# 1     89
# Name: race/ethnicity, dtype: int64

# %%
data["parental level of education"]=le.fit_transform(data["parental level of education"])
data["parental level of education"].value_counts()
# Out:
# 4    226
# 0    222
# 2    196
# 5    179
# 1    118
# 3     59
# Name: parental level of education, dtype: int64

# %%
data["gender"]=le.fit_transform(data["gender"])
data["pass_math"]=le.fit_transform(data["pass_math"])
data["pass_reading"]=le.fit_transform(data["pass_reading"])
data["pass_writing"]=le.fit_transform(data["pass_writing"])
data["Status"]=le.fit_transform(data["Status"])

# %%
data["grades"]=data["grades"].replace("O",0)
data["grades"]=data["grades"].replace("A",1)
data["grades"]=data["grades"].replace("B",2)
data["grades"]=data["grades"].replace("C",3)
data["grades"]=data["grades"].replace("D",4)
data["grades"]=data["grades"].replace("E",5)

# %%
data["race/ethnicity"].value_counts()
# Out:
# 3    319
# 4    262
# 2    190
# 5    140
# 1     89
# Name: race/ethnicity, dtype: int64

# %% [markdown]
# # Model building

# %%
x=data.iloc[:,:14]
y=data.iloc[:,14]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=45)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (750, 14)
# (250, 14)
# (750,)
# (250,)

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
x_train=mm.fit_transform(x_train)
x_test=mm.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [134], in <cell line: 1>()
# ----> 1 model.plot()
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'plot'

# %%
print(model.score(x_train,y_train))
print(model.score(x_test,y_test))
# Out:
# 1.0
# 1.0

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)

sns.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report
cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        29
#            2       1.00      1.00      1.00        72
#            3       1.00      1.00      1.00        59
#            4       1.00      1.00      1.00        64
#            5       1.00      1.00      1.00        16
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
yhat=lr.predict(x_test)
# Out:
# C:\Users\Ayush kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
cr1=classification_report(y_test,yhat)
print(cr1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.20      0.29        10
#            1       0.68      0.59      0.63        29
#            2       0.84      0.85      0.84        72
#            3       0.79      0.95      0.86        59
#            4       0.98      0.94      0.96        64
#            5       1.00      1.00      1.00        16
#
#     accuracy                           0.85       250
#    macro avg       0.80      0.75      0.76       250
# weighted avg       0.84      0.85      0.84       250

# %%
accuracy_score(y_test,yhat)
# Out:
# 0.848

# %%
# Out:
# RandomForestClassifier()
